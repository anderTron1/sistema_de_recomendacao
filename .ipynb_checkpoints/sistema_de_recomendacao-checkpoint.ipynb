# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import time

# %%
#FUNÇÃO APENAS PARA CRIAR O DATAFRAME SIMULADO
def getDF():
    dic__ = {"User_1":[np.nan, np.nan, np.nan, 1, 7, 2, 3, 8],
         "User_2":[9,10,2,2,6,5,3,8],
         "User_3":[4, 7, 9, 6,6,10,10,2],
         "User_4":[np.nan, 7, 9, 5, 5, 10, 9, 1],
         "User_5":[7.0,6.0,3.0,8.0,3,4.0,3.0, 2],
         "User_6":[np.nan, np.nan, 9, 9,6,8,9,np.nan],
         "User_7":[3,5,4,4,3,3,9,np.nan],
         "User_8":[10,10,10,10,2,2,2,2],
         "User_9":[9,9,np.nan,8,3,3,1,np.nan],
         "User_10":[9,8,10,9,3,4,2,1],
         "User_11":[4,4,3,3,9,9,8,10],
         "User_12":[2,2,4,1,8,10,10,9],
         "User_13":[1,4,1,3,7,10,7,8],
         "User_14":[3,3,2,1,1,10, np.nan,10],
         "User_15":[9,9,8,10,4,2,np.nan,1]
        }
    df = pd.DataFrame(dic__).T
    df.columns = ['Film_'+str(int(i+1)) for i in range(8)]
    return df

# %%
getDF()
# Out:
#          Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# User_1      NaN     NaN     NaN     1.0     7.0     2.0     3.0     8.0
# User_2      9.0    10.0     2.0     2.0     6.0     5.0     3.0     8.0
# User_3      4.0     7.0     9.0     6.0     6.0    10.0    10.0     2.0
# User_4      NaN     7.0     9.0     5.0     5.0    10.0     9.0     1.0
# User_5      7.0     6.0     3.0     8.0     3.0     4.0     3.0     2.0
# User_6      NaN     NaN     9.0     9.0     6.0     8.0     9.0     NaN
# User_7      3.0     5.0     4.0     4.0     3.0     3.0     9.0     NaN
# User_8     10.0    10.0    10.0    10.0     2.0     2.0     2.0     2.0
# User_9      9.0     9.0     NaN     8.0     3.0     3.0     1.0     NaN
# User_10     9.0     8.0    10.0     9.0     3.0     4.0     2.0     1.0
# User_11     4.0     4.0     3.0     3.0     9.0     9.0     8.0    10.0
# User_12     2.0     2.0     4.0     1.0     8.0    10.0    10.0     9.0
# User_13     1.0     4.0     1.0     3.0     7.0    10.0     7.0     8.0
# User_14     3.0     3.0     2.0     1.0     1.0    10.0     NaN    10.0
# User_15     9.0     9.0     8.0    10.0     4.0     2.0     NaN     1.0

# %% [markdown]
# ### Medidas de similaridade

# %%
from sklearn.metrics.pairwise import nan_euclidean_distances

def euclid_dist(x, y):
    v = np.vstack([x,y])
    if np.isnan(nan_euclidean_distances(v)[0,1]):
        return 1e10
    else:
        return nan_euclidean_distances(v)[0,1]

# %%
x = np.array([1,1])
y = np.array([2,2])

dist_xy = euclid_dist(x,y)

plt.title('Distância entre x e y: ' + str(np.round(dist_xy, 3)), fontsize=14, fontweight='bold')
plt.scatter([x[0], y[0]], [x[1], y[1]], s = 100, c = 'black')
plt.xlim(0,10)
plt.ylim(0,10)
plt.xticks(range(11))
plt.yticks(range(11))
plt.grid()
plt.show()

# %%
x = np.array([1,1])
y = np.array([5,4])

dist_xy = euclid_dist(x,y)

plt.title('Distância entre x e y: ' + str(np.round(dist_xy, 3)), fontsize=14, fontweight='bold')
plt.scatter([x[0], y[0]], [x[1], y[1]], s = 100, c = 'black')
plt.xlim(0,10)
plt.ylim(0,10)
plt.xticks(range(11))
plt.yticks(range(11))
plt.grid()
plt.show()

# %%
x = np.array([1,1])
y = np.array([9,2])

dist_xy = euclid_dist(x,y)

plt.title('Distância entre x e y: ' + str(np.round(dist_xy, 3)), fontsize=14, fontweight='bold')
plt.scatter([x[0], y[0]], [x[1], y[1]], s = 100, c = 'black')
plt.xlim(0,10)
plt.ylim(0,10)
plt.xticks(range(11))
plt.yticks(range(11))
plt.grid()
plt.show()

# %%
x = np.random.randint(0,10, size=5)
y = np.random.randint(0,10, size=5)

print('x: ', x)
print('y: ', y)

print()
print('distância')
dist_xy = euclid_dist(x, y)
print(dist_xy)
# Out:
# x:  [6 1 7 3 5]
# y:  [0 4 1 0 1]
#
# distância
# 10.295630140987

# %%
x = np.random.randint(0,10, size=30)
y = np.random.randint(0,10, size=30)

print('x: ', x)
print('y: ', y)

print()
print('distância')
dist_xy = euclid_dist(x, y)
print(dist_xy)
# Out:
# x:  [6 0 1 2 4 2 7 2 3 7 3 9 8 0 2 2 6 3 3 8 8 3 6 4 3 2 0 5 8 1]
# y:  [3 5 9 2 8 6 3 7 6 2 0 4 0 7 5 9 3 1 5 1 6 9 5 4 8 5 8 8 9 5]
#
# distância
# 25.317977802344327

# %%
x = np.array([1,3,10, np.nan, 5, np.nan])
y = np.array([5, 2, np.nan, 2, 0, np.nan])

print('x: ', x)
print('y: ', y)

print()
print('distância')
dist_xy = euclid_dist(x, y)
print(dist_xy)
# Out:
# x:  [ 1.  3. 10. nan  5. nan]
# y:  [ 5.  2. nan  2.  0. nan]
#
# distância
# 9.16515138991168

# %%
class Similaridade():
    def __init__(self, dataframe):
        self.df = dataframe
        self.lista_user = dataframe.index.tolist()
        self.lista_filmes = dataframe.columns.tolist()
        
    def similaridadeUsuarios(self, user, sorted_list = True):
        nota_user = self.df.loc[user,:].values
        L = []
        for u in self.lista_user:
            if u == user:
                continue
            else:
                nota_u = self.df.loc[u,:].values
                dist = euclid_dist(nota_user, nota_u)
                similaridade = 1 / (1 + dist)
                L.append([u, similaridade])
        if sorted_list:
            L.sort(key = lambda s: s[1], reverse = True)
            return L
        else:
            return L
        
    def similaridadeFilme(self, filme, sorted_list = True):
        nota_filme = self.df.T.loc[filme, :].values
        L = []
        for f in self.lista_filmes:
            if f == filme:
                continue
            else:
                nota_f = self.df.T.loc[f, :].values
                dist = euclid_dist(nota_filme, nota_f)
                similaridade = 1 / (1 + dist)
                L.append([f,similaridade])
        if sorted_list:
            L.sort(key = lambda s: s[1], reverse = True)
            return L
        else:
            return L
        
    def similaridade_etre_dois_user(self, user1, user2):
        return [x[1] for x in self.similiridadeUser(user1) if x[x] == user2][0] 
    
    def similaridade_etre_dois_filmes(self, filme1, filme2):
        return [x[1] for x in self.similaridadeFilme(filme) if x[0] == filme2 ][0]

# %%
df = getDF()

# %%
df
# Out:
#          Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# User_1      NaN     NaN     NaN     1.0     7.0     2.0     3.0     8.0
# User_2      9.0    10.0     2.0     2.0     6.0     5.0     3.0     8.0
# User_3      4.0     7.0     9.0     6.0     6.0    10.0    10.0     2.0
# User_4      NaN     7.0     9.0     5.0     5.0    10.0     9.0     1.0
# User_5      7.0     6.0     3.0     8.0     3.0     4.0     3.0     2.0
# User_6      NaN     NaN     9.0     9.0     6.0     8.0     9.0     NaN
# User_7      3.0     5.0     4.0     4.0     3.0     3.0     9.0     NaN
# User_8     10.0    10.0    10.0    10.0     2.0     2.0     2.0     2.0
# User_9      9.0     9.0     NaN     8.0     3.0     3.0     1.0     NaN
# User_10     9.0     8.0    10.0     9.0     3.0     4.0     2.0     1.0
# User_11     4.0     4.0     3.0     3.0     9.0     9.0     8.0    10.0
# User_12     2.0     2.0     4.0     1.0     8.0    10.0    10.0     9.0
# User_13     1.0     4.0     1.0     3.0     7.0    10.0     7.0     8.0
# User_14     3.0     3.0     2.0     1.0     1.0    10.0     NaN    10.0
# User_15     9.0     9.0     8.0    10.0     4.0     2.0     NaN     1.0

# %%
sim = Similaridade(dataframe=df)

# %%
sim.df
# Out:
#          Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# User_1      NaN     NaN     NaN     1.0     7.0     2.0     3.0     8.0
# User_2      9.0    10.0     2.0     2.0     6.0     5.0     3.0     8.0
# User_3      4.0     7.0     9.0     6.0     6.0    10.0    10.0     2.0
# User_4      NaN     7.0     9.0     5.0     5.0    10.0     9.0     1.0
# User_5      7.0     6.0     3.0     8.0     3.0     4.0     3.0     2.0
# User_6      NaN     NaN     9.0     9.0     6.0     8.0     9.0     NaN
# User_7      3.0     5.0     4.0     4.0     3.0     3.0     9.0     NaN
# User_8     10.0    10.0    10.0    10.0     2.0     2.0     2.0     2.0
# User_9      9.0     9.0     NaN     8.0     3.0     3.0     1.0     NaN
# User_10     9.0     8.0    10.0     9.0     3.0     4.0     2.0     1.0
# User_11     4.0     4.0     3.0     3.0     9.0     9.0     8.0    10.0
# User_12     2.0     2.0     4.0     1.0     8.0    10.0    10.0     9.0
# User_13     1.0     4.0     1.0     3.0     7.0    10.0     7.0     8.0
# User_14     3.0     3.0     2.0     1.0     1.0    10.0     NaN    10.0
# User_15     9.0     9.0     8.0    10.0     4.0     2.0     NaN     1.0

# %%
sim.lista_filmes
# Out:
# ['Film_1',
#  'Film_2',
#  'Film_3',
#  'Film_4',
#  'Film_5',
#  'Film_6',
#  'Film_7',
#  'Film_8']

# %%
sim.lista_user
# Out:
# ['User_1',
#  'User_2',
#  'User_3',
#  'User_4',
#  'User_5',
#  'User_6',
#  'User_7',
#  'User_8',
#  'User_9',
#  'User_10',
#  'User_11',
#  'User_12',
#  'User_13',
#  'User_14',
#  'User_15']

# %%
sim.similaridadeUsuarios('User_1')
# Out:
# [['User_2', 0.1924840598000365],
#  ['User_7', 0.08240267256634183],
#  ['User_13', 0.07940855619903711],
#  ['User_11', 0.07855272795675068],
#  ['User_9', 0.0779292055122247],
#  ['User_5', 0.07162563710668096],
#  ['User_12', 0.06865934407787179],
#  ['User_14', 0.06484157054036695],
#  ['User_10', 0.06392879181901828],
#  ['User_8', 0.06201113398134867],
#  ['User_4', 0.057326814524408215],
#  ['User_6', 0.05697049581409102],
#  ['User_15', 0.056582425994704214],
#  ['User_3', 0.05639139975154663]]

# %%
df.loc[['User_1', 'User_2']]
# Out:
#         Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# User_1     NaN     NaN     NaN     1.0     7.0     2.0     3.0     8.0
# User_2     9.0    10.0     2.0     2.0     6.0     5.0     3.0     8.0

# %%
df.loc[['User_1', 'User_3']]
# Out:
#         Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# User_1     NaN     NaN     NaN     1.0     7.0     2.0     3.0     8.0
# User_3     4.0     7.0     9.0     6.0     6.0    10.0    10.0     2.0

# %%
sim.similaridadeFilme('Film_8')
# Out:
# [['Film_5', 0.07147768141142521],
#  ['Film_6', 0.058133276275409755],
#  ['Film_7', 0.05648666578593548],
#  ['Film_2', 0.04067130131368077],
#  ['Film_1', 0.03899013204902304],
#  ['Film_3', 0.035830816042996094],
#  ['Film_4', 0.035779422208098904]]

# %%
df.T
# Out:
#         User_1  User_2  User_3  User_4  User_5  User_6  User_7  User_8  \
# Film_1     NaN     9.0     4.0     NaN     7.0     NaN     3.0    10.0
# Film_2     NaN    10.0     7.0     7.0     6.0     NaN     5.0    10.0
# Film_3     NaN     2.0     9.0     9.0     3.0     9.0     4.0    10.0
# Film_4     1.0     2.0     6.0     5.0     8.0     9.0     4.0    10.0
# Film_5     7.0     6.0     6.0     5.0     3.0     6.0     3.0     2.0
# Film_6     2.0     5.0    10.0    10.0     4.0     8.0     3.0     2.0
# Film_7     3.0     3.0    10.0     9.0     3.0     9.0     9.0     2.0
# Film_8     8.0     8.0     2.0     1.0     2.0     NaN     NaN     2.0
#
#         User_9  User_10  User_11  User_12  User_13  User_14  User_15
# Film_1     9.0      9.0      4.0      2.0      1.0      3.0      9.0
# Film_2     9.0      8.0      4.0      2.0      4.0      3.0      9.0
# Film_3     NaN     10.0      3.0      4.0      1.0      2.0      8.0
# Film_4     8.0      9.0      3.0      1.0      3.0      1.0     10.0
# Film_5     3.0      3.0      9.0      8.0      7.0      1.0      4.0
# Film_6     3.0      4.0      9.0     10.0     10.0     10.0      2.0
# Film_7     1.0      2.0      8.0     10.0      7.0      NaN      NaN
# Film_8     NaN      1.0     10.0      9.0      8.0     10.0      1.0

# %%
df.T.loc[['Film_8', 'Film_5']]
# Out:
#         User_1  User_2  User_3  User_4  User_5  User_6  User_7  User_8  \
# Film_8     8.0     8.0     2.0     1.0     2.0     NaN     NaN     2.0
# Film_5     7.0     6.0     6.0     5.0     3.0     6.0     3.0     2.0
#
#         User_9  User_10  User_11  User_12  User_13  User_14  User_15
# Film_8     NaN      1.0     10.0      9.0      8.0     10.0      1.0
# Film_5     3.0      3.0      9.0      8.0      7.0      1.0      4.0

# %%
df.T.loc[['Film_8', 'Film_4']]
# Out:
#         User_1  User_2  User_3  User_4  User_5  User_6  User_7  User_8  \
# Film_8     8.0     8.0     2.0     1.0     2.0     NaN     NaN     2.0
# Film_4     1.0     2.0     6.0     5.0     8.0     9.0     4.0    10.0
#
#         User_9  User_10  User_11  User_12  User_13  User_14  User_15
# Film_8     NaN      1.0     10.0      9.0      8.0     10.0      1.0
# Film_4     8.0      9.0      3.0      1.0      3.0      1.0     10.0

# %% [markdown]
# ## 3. Filtros colaborativos baseados em USUÁRIOS: implementação

# %%
class InfoRec():
    def __init__(self, dataframe):
        self.df = dataframe
        
    def getFilmes(self, user):
        return self.df.loc[user]
    
    def getUsers(self, filme):
        return self.df.T.loc[filme]
    
    def getPossibleMovies(self, user):
        return self.getFilmes(user)[np.isnan(self.getFilmes(user))].index.tolist()
    
    def getPossibleUsers(self, filme):
        return self.getUsers(filme)[np.isnan(self.getUsers(filme))].index.tolist()

# %%
df
# Out:
#          Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# User_1      NaN     NaN     NaN     1.0     7.0     2.0     3.0     8.0
# User_2      9.0    10.0     2.0     2.0     6.0     5.0     3.0     8.0
# User_3      4.0     7.0     9.0     6.0     6.0    10.0    10.0     2.0
# User_4      NaN     7.0     9.0     5.0     5.0    10.0     9.0     1.0
# User_5      7.0     6.0     3.0     8.0     3.0     4.0     3.0     2.0
# User_6      NaN     NaN     9.0     9.0     6.0     8.0     9.0     NaN
# User_7      3.0     5.0     4.0     4.0     3.0     3.0     9.0     NaN
# User_8     10.0    10.0    10.0    10.0     2.0     2.0     2.0     2.0
# User_9      9.0     9.0     NaN     8.0     3.0     3.0     1.0     NaN
# User_10     9.0     8.0    10.0     9.0     3.0     4.0     2.0     1.0
# User_11     4.0     4.0     3.0     3.0     9.0     9.0     8.0    10.0
# User_12     2.0     2.0     4.0     1.0     8.0    10.0    10.0     9.0
# User_13     1.0     4.0     1.0     3.0     7.0    10.0     7.0     8.0
# User_14     3.0     3.0     2.0     1.0     1.0    10.0     NaN    10.0
# User_15     9.0     9.0     8.0    10.0     4.0     2.0     NaN     1.0

# %%
info = InfoRec(dataframe=df)

# %%
info.getFilmes('User_1')
# Out:
# Film_1    NaN
# Film_2    NaN
# Film_3    NaN
# Film_4    1.0
# Film_5    7.0
# Film_6    2.0
# Film_7    3.0
# Film_8    8.0
# Name: User_1, dtype: float64

# %%
info.getUsers('Film_1')
# Out:
# User_1      NaN
# User_2      9.0
# User_3      4.0
# User_4      NaN
# User_5      7.0
# User_6      NaN
# User_7      3.0
# User_8     10.0
# User_9      9.0
# User_10     9.0
# User_11     4.0
# User_12     2.0
# User_13     1.0
# User_14     3.0
# User_15     9.0
# Name: Film_1, dtype: float64

# %%
info.getPossibleMovies('User_1')
# Out:
# ['Film_1', 'Film_2', 'Film_3']

# %%
info.getPossibleUsers('Film_1')
# Out:
# ['User_1', 'User_4', 'User_6']

# %%
user = 'User_1'

# %%
df1 = pd.DataFrame(sim.similaridadeUsuarios(user, sorted_list=False), columns=['usuario', 'similaridade'])
df1
# Out:
#     usuario  similaridade
# 0    User_2      0.192484
# 1    User_3      0.056391
# 2    User_4      0.057327
# 3    User_5      0.071626
# 4    User_6      0.056970
# 5    User_7      0.082403
# 6    User_8      0.062011
# 7    User_9      0.077929
# 8   User_10      0.063929
# 9   User_11      0.078553
# 10  User_12      0.068659
# 11  User_13      0.079409
# 12  User_14      0.064842
# 13  User_15      0.056582

# %%
df2 = sim.df.loc[df1.usuario,].reset_index().rename(columns={'index':'usuario'})
df2
# Out:
#     usuario  Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# 0    User_2     9.0    10.0     2.0     2.0     6.0     5.0     3.0     8.0
# 1    User_3     4.0     7.0     9.0     6.0     6.0    10.0    10.0     2.0
# 2    User_4     NaN     7.0     9.0     5.0     5.0    10.0     9.0     1.0
# 3    User_5     7.0     6.0     3.0     8.0     3.0     4.0     3.0     2.0
# 4    User_6     NaN     NaN     9.0     9.0     6.0     8.0     9.0     NaN
# 5    User_7     3.0     5.0     4.0     4.0     3.0     3.0     9.0     NaN
# 6    User_8    10.0    10.0    10.0    10.0     2.0     2.0     2.0     2.0
# 7    User_9     9.0     9.0     NaN     8.0     3.0     3.0     1.0     NaN
# 8   User_10     9.0     8.0    10.0     9.0     3.0     4.0     2.0     1.0
# 9   User_11     4.0     4.0     3.0     3.0     9.0     9.0     8.0    10.0
# 10  User_12     2.0     2.0     4.0     1.0     8.0    10.0    10.0     9.0
# 11  User_13     1.0     4.0     1.0     3.0     7.0    10.0     7.0     8.0
# 12  User_14     3.0     3.0     2.0     1.0     1.0    10.0     NaN    10.0
# 13  User_15     9.0     9.0     8.0    10.0     4.0     2.0     NaN     1.0

# %%
df3 = df1.merge(df2, on='usuario', how='inner')
df3
# Out:
#     usuario  similaridade  Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  \
# 0    User_2      0.192484     9.0    10.0     2.0     2.0     6.0     5.0
# 1    User_3      0.056391     4.0     7.0     9.0     6.0     6.0    10.0
# 2    User_4      0.057327     NaN     7.0     9.0     5.0     5.0    10.0
# 3    User_5      0.071626     7.0     6.0     3.0     8.0     3.0     4.0
# 4    User_6      0.056970     NaN     NaN     9.0     9.0     6.0     8.0
# 5    User_7      0.082403     3.0     5.0     4.0     4.0     3.0     3.0
# 6    User_8      0.062011    10.0    10.0    10.0    10.0     2.0     2.0
# 7    User_9      0.077929     9.0     9.0     NaN     8.0     3.0     3.0
# 8   User_10      0.063929     9.0     8.0    10.0     9.0     3.0     4.0
# 9   User_11      0.078553     4.0     4.0     3.0     3.0     9.0     9.0
# 10  User_12      0.068659     2.0     2.0     4.0     1.0     8.0    10.0
# 11  User_13      0.079409     1.0     4.0     1.0     3.0     7.0    10.0
# 12  User_14      0.064842     3.0     3.0     2.0     1.0     1.0    10.0
# 13  User_15      0.056582     9.0     9.0     8.0    10.0     4.0     2.0
#
#     Film_7  Film_8
# 0      3.0     8.0
# 1     10.0     2.0
# 2      9.0     1.0
# 3      3.0     2.0
# 4      9.0     NaN
# 5      9.0     NaN
# 6      2.0     2.0
# 7      1.0     NaN
# 8      2.0     1.0
# 9      8.0    10.0
# 10    10.0     9.0
# 11     7.0     8.0
# 12     NaN    10.0
# 13     NaN     1.0

# %%
info.getPossibleMovies(user)
# Out:
# ['Film_1', 'Film_2', 'Film_3']

# %%
dic_recs = {}

for f in info.getPossibleMovies(user):
    sims = df3.similaridade
    
    nota_f = df3[f]
    
    total_sim_vs_notafilme = (sims * nota_f.fillna(0)).sum()
    total_sims = sims[~sims.index.isin(nota_f.loc[np.isnan(nota_f)].index.tolist())].sum()
    
    dic_recs[f] = total_sim_vs_notafilme / total_sims
    
dic_recs
# Out:
# {'Film_1': 6.114307160765262,
#  'Film_2': 6.786057983472178,
#  'Film_3': 4.940648740807049}

# %%
class UserBasedColabFiltering():
    def __init__(self, dataframe):
        self.df = dataframe
        self.sim = Similaridade(dataframe = self.df)
        self.info = InfoRec(dataframe = self.df)
        
    def makeRec(self, user):
        df1 = pd.DataFrame(self.sim.similaridadeUsuarios(user, sorted_list = False), 
              columns = ['usuario', 'similaridade'])
        df2 = self.df.loc[df1.usuario, ].reset_index().rename(columns = {"index":"usuario"})
        df3 = df1.merge(df2, on = 'usuario', how = 'inner')
        dic_recs = {}
        for f in self.info.getPossibleMovies(user): 
            sims = df3.similaridade
            nota_f = df3[f]
            total_sim_vs_notafilme = (sims * nota_f.fillna(0)).sum()
            total_sims = sims[~sims.index.isin(nota_f.loc[np.isnan(nota_f)].index.tolist())].sum()
            dic_recs[f] = total_sim_vs_notafilme / total_sims
        return dic_recs

# %%
usb = UserBasedColabFiltering(dataframe=df)

# %%
usb.makeRec('User_1')
# Out:
# {'Film_1': 6.114307160765262,
#  'Film_2': 6.786057983472178,
#  'Film_3': 4.940648740807049}

# %%
usb.makeRec('User_8')
# Out:
# {}

# %%
usb.makeRec('User_9')
# Out:
# {'Film_3': 6.869332239924477, 'Film_8': 3.4132070814421516}

# %%
f = 'Film_1'

# %%
df1 = pd.DataFrame(sim.similaridadeFilme(f, sorted_list=False), columns=['filme', 'similaridade'])
df1
# Out:
#     filme  similaridade
# 0  Film_2      0.151741
# 1  Film_3      0.079246
# 2  Film_4      0.098508
# 3  Film_5      0.049820
# 4  Film_6      0.040286
# 5  Film_7      0.038447
# 6  Film_8      0.038990

# %%
df2 = sim.df.T.loc[df1.filme, ].reset_index().rename(columns={'index':'filme'})
df2
# Out:
#     filme  User_1  User_2  User_3  User_4  User_5  User_6  User_7  User_8  \
# 0  Film_2     NaN    10.0     7.0     7.0     6.0     NaN     5.0    10.0
# 1  Film_3     NaN     2.0     9.0     9.0     3.0     9.0     4.0    10.0
# 2  Film_4     1.0     2.0     6.0     5.0     8.0     9.0     4.0    10.0
# 3  Film_5     7.0     6.0     6.0     5.0     3.0     6.0     3.0     2.0
# 4  Film_6     2.0     5.0    10.0    10.0     4.0     8.0     3.0     2.0
# 5  Film_7     3.0     3.0    10.0     9.0     3.0     9.0     9.0     2.0
# 6  Film_8     8.0     8.0     2.0     1.0     2.0     NaN     NaN     2.0
#
#    User_9  User_10  User_11  User_12  User_13  User_14  User_15
# 0     9.0      8.0      4.0      2.0      4.0      3.0      9.0
# 1     NaN     10.0      3.0      4.0      1.0      2.0      8.0
# 2     8.0      9.0      3.0      1.0      3.0      1.0     10.0
# 3     3.0      3.0      9.0      8.0      7.0      1.0      4.0
# 4     3.0      4.0      9.0     10.0     10.0     10.0      2.0
# 5     1.0      2.0      8.0     10.0      7.0      NaN      NaN
# 6     NaN      1.0     10.0      9.0      8.0     10.0      1.0

# %%
df3 = df1.merge(df2, on = 'filme', how = 'inner')
df3
# Out:
#     filme  similaridade  User_1  User_2  User_3  User_4  User_5  User_6  \
# 0  Film_2      0.151741     NaN    10.0     7.0     7.0     6.0     NaN
# 1  Film_3      0.079246     NaN     2.0     9.0     9.0     3.0     9.0
# 2  Film_4      0.098508     1.0     2.0     6.0     5.0     8.0     9.0
# 3  Film_5      0.049820     7.0     6.0     6.0     5.0     3.0     6.0
# 4  Film_6      0.040286     2.0     5.0    10.0    10.0     4.0     8.0
# 5  Film_7      0.038447     3.0     3.0    10.0     9.0     3.0     9.0
# 6  Film_8      0.038990     8.0     8.0     2.0     1.0     2.0     NaN
#
#    User_7  User_8  User_9  User_10  User_11  User_12  User_13  User_14  \
# 0     5.0    10.0     9.0      8.0      4.0      2.0      4.0      3.0
# 1     4.0    10.0     NaN     10.0      3.0      4.0      1.0      2.0
# 2     4.0    10.0     8.0      9.0      3.0      1.0      3.0      1.0
# 3     3.0     2.0     3.0      3.0      9.0      8.0      7.0      1.0
# 4     3.0     2.0     3.0      4.0      9.0     10.0     10.0     10.0
# 5     9.0     2.0     1.0      2.0      8.0     10.0      7.0      NaN
# 6     NaN     2.0     NaN      1.0     10.0      9.0      8.0     10.0
#
#    User_15
# 0      9.0
# 1      8.0
# 2     10.0
# 3      4.0
# 4      2.0
# 5      NaN
# 6      1.0

# %%
info.getPossibleUsers(f)
# Out:
# ['User_1', 'User_4', 'User_6']

# %%
dic_recs = {}

for u in info.getPossibleUsers(f):
    sims = df3.similaridade
    
    nota_u = df3[u]
    
    total_sim_vs_notafilme = (sims * nota_u.fillna(0)).sum()
    total_sims = sims[~sims.index.isin(nota_u.loc[np.isnan(nota_u)].index.tolist())].sum()
    
    dic_recs[u] = total_sim_vs_notafilme / total_sims
    
dic_recs
# Out:
# {'User_1': 3.589846973408298,
#  'User_4': 6.649218910791067,
#  'User_6': 8.38053388736287}

# %%
class ItemBasedColabFiltering():

    def __init__(self, dataframe):
        self.df = dataframe
        self.sim = Similaridade(dataframe = self.df)
        self.info = InfoRec(dataframe = self.df)
        
    def makeRec(self, filme):
        df1 = pd.DataFrame(self.sim.similaridadeFilmes(filme, sorted_list = False), 
                           columns = ['filme', 'similaridade'])
        df2 = self.df.T.loc[df1.filme, ].reset_index().rename(columns = {"index":"filme"})
        df3 = df1.merge(df2, on = 'filme', how = 'inner')
        dic_recs = {}
        for u in self.info.getPossibleUsers(filme):
            sims = df3.similaridade
            nota_u = df3[u]
            total_sim_vs_notafilme = (sims * nota_u.fillna(0)).sum()
            total_sims = sims[~sims.index.isin(nota_u.loc[np.isnan(nota_u)].index.tolist())].sum()
            dic_recs[u] = total_sim_vs_notafilme / total_sims
        return dic_recs

# %%
user_based = UserBasedColabFiltering(dataframe = df)
item_based = ItemBasedColabFiltering(dataframe = df)

# %%
df
# Out:
#          Film_1  Film_2  Film_3  Film_4  Film_5  Film_6  Film_7  Film_8
# User_1      NaN     NaN     NaN     1.0     7.0     2.0     3.0     8.0
# User_2      9.0    10.0     2.0     2.0     6.0     5.0     3.0     8.0
# User_3      4.0     7.0     9.0     6.0     6.0    10.0    10.0     2.0
# User_4      NaN     7.0     9.0     5.0     5.0    10.0     9.0     1.0
# User_5      7.0     6.0     3.0     8.0     3.0     4.0     3.0     2.0
# User_6      NaN     NaN     9.0     9.0     6.0     8.0     9.0     NaN
# User_7      3.0     5.0     4.0     4.0     3.0     3.0     9.0     NaN
# User_8     10.0    10.0    10.0    10.0     2.0     2.0     2.0     2.0
# User_9      9.0     9.0     NaN     8.0     3.0     3.0     1.0     NaN
# User_10     9.0     8.0    10.0     9.0     3.0     4.0     2.0     1.0
# User_11     4.0     4.0     3.0     3.0     9.0     9.0     8.0    10.0
# User_12     2.0     2.0     4.0     1.0     8.0    10.0    10.0     9.0
# User_13     1.0     4.0     1.0     3.0     7.0    10.0     7.0     8.0
# User_14     3.0     3.0     2.0     1.0     1.0    10.0     NaN    10.0
# User_15     9.0     9.0     8.0    10.0     4.0     2.0     NaN     1.0

# %%
usb.makeRec("User_1")
# Out:
# {'Film_1': 6.114307160765262,
#  'Film_2': 6.786057983472178,
#  'Film_3': 4.940648740807049}

# %% [markdown]
# ### Fatoração matricial

# %% [markdown]
# #### Filtros colaborativos baseados em modelos: Fatoração matricial

# %% [markdown]
# O objetivo é
#
# - Decompor a matriz de interação no produto de duas matrizes bem menores:
#     - Matriz de fatoração dos usuários;
#     - Matriz de fatoração dos itens;
#     - A multiplicação entre essas duas matrizes deve gerar uma matriz resultante similar a matriz de interação original
#
# **Matematicamente**, a principal hipótese por trás da foração matricial é que existe um **espaço dimensional latente de baixa dimensão** no qual podemos **representar** tanto os usuários quanto os **itens**. Além disso, podemos estimar a interação entre usuários e itens a partir deste produto matricial.

# %%
def MatrixFactorization():
    def __init__(self, dataframe, k, steps, alpha, beta):
        self.df=dataframe
        self.K = k
        self.steps = steps
        self.alpha = alpha
        self.beta = beta
        
    def fit(self):
        t0 = time.time()
        
        R = self.df.values
        N, M = R.shape
        
        #inicio aleatorio
        P = np.random.rand(N, self.K)
        Q = np.random.rand(self.K, M)
        
        lsita_erro_step = []
        
        #loop
        for step in range(self.steps):
            mse_total_step = 0
            #varrendo todas as entradas da matriz R
            for i in range(len(R)):
                for j in range(len(R[i])):
                    #validando se o valor associado está preenchido
                    if R[i][j] > 0:
                        
                        #calculando o erro:
                        eij = R[i][j] - np.dot(P[i,:], Q[:,j])
                        mse_total_step += (eij)**2
                        #alterando os valores
                        for k in range(self.K):
                            P[i][k] = P[i][k] + self.alpha * ( 2 * eij * Q[k][j] - self.beta * P[i][k])
                            Q[k][j] = Q[k][j] + self.alpha * ( 2 * eij * P[i][k] - self.beta * Q[k][j])
            lista_erro_step.append(mse_total_step)
            
        self.P = P
        self.Q = Q
        
        self.lista_erro_step = lista_erro_step
        t1 = time.time()
        print('Fatoração conluida. Tempo aproximado: ', int((t1-t0)/60)+1, ' Minuto(s).')
        
    def predict(self):
        return self.P.dot(self.Q)
    
    def print_MSE_steps(self):
        plt.figure(figsize=[15,6])
        plt.title('Custo total por Step', fontsize=16, fontweight = 'bold')
        plt.xlabel('Step', fontsize=14, fontweight='bold')
        plt.ylabel('Erro', fontsize=14, fontweight='bold')
        plt.plot(range(1, 1+self.steps), self.lista_erro_step, c = 'blue', lw =2)
        plt.grid()
# Out:
#   File "/tmp/ipykernel_6748/2590067534.py", line 1
#     def MatrixFactorization:
#                            ^
# SyntaxError: invalid syntax

# %%
fat = MatrixFactorization(dataframe = df, K = 3, steps = 2000, alpha = 0.002, beta = 0.02)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6748/1391883990.py in <module>
# ----> 1 fat = MatrixFactorization(dataframe = df, K = 3, steps = 2000, alpha = 0.002, beta = 0.02)
#
# TypeError: MatrixFactorization() got an unexpected keyword argument 'dataframe'
